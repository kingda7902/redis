# %%
#FetchAll
#!/usr/bin/python3
# -*- utf8 -*-
#導入PyMySQL庫
import pymysql as mariadb
#測試連接MariaDB數據庫
try:
    conn = mariadb.connect(
        host='10.120.27.2',
        user='root',
        passwd='1234',
        db='rental',
        charset='utf8mb4'
    )
    #設置cursor
    cursor = conn.cursor()
    #撰寫SQL語句
    sql = "SELECT * FROM rentInfo LIMIT 100;"
    #sql = "show tables;"
    try:
        cursor.execute(sql)
        results = cursor.fetchall()
        for item in results:
            #typeId = item[0]
            #typename = item[1]
            print(item)
    except Exception as e:
        print('Execute Failed!\nError Code is %s;\nError Content is %s;' % (e.args[0],e.args[1]))
    #關閉cursor
    cursor.close()
    #關閉數據庫連接
    conn.close()
except Exception as e:
    print('Connection Failed!\nError Code is %s;\nError Content is %s;' % (e.args[0],e.args[1]))
# Out:
# (1, 'http://rent.yungching.com.tw/house/967334/', '2016-12-29', '首鼎四房', '新北市淡水區新春街', '住', 'N', 'N', 'N', 'N', 'Y', Decimal('62.34'), 25000, 5, 0, '水泥', 'NA', '房屋描述首鼎四房交通便利任你行任您輕鬆散步的單純社區文風鼎盛置身優質學區豪華得意居有薪既可入住', Decimal('25.18183680000000000'), Decimal('121.44048660000000000'), 251)
# (2, 'http://rent.yungching.com.tw/house/963399/', '2016-09-30', '台北灣江南2房高檔裝潢含車位', '新北市淡水區濱海路三段', '住', 'N', 'N', 'N', 'N', 'Y', Decimal('50.70'), 32000, 2, 11, '11', 'NA', '房屋描述台北灣江南2房高檔裝潢含車位台北灣江南頤和渡假首選，時尚高檔裝潢，中歐混搭風格，正前方就是台北海洋技術學院，不論在這教書的老師或上課的學生都相當便利。公司田溪環繞基地，讓社區充滿了大自然的味道。', Decimal('25.19771860000000000'), Decimal('121.42168500000000000'), 251)
# (3, 'http://rent.yungching.com.tw/house/949195/', '2017-08-07', '川普大坪數大空間,全新交屋！含車含管', '新北市淡水區淡金路一段', '住', 'N', 'N', 'N', 'N', 'Y', Decimal('44.97'), 25000, 9, 15, 'NA', 'NA', '房屋描述川普大坪數大空間,全新交屋！含車含管未來捷運完工後，一下樓過個馬路就可以搭捷運，「川普G3棧」的位置是目前淡水區機能最完整的區域，即便淡海區也都是依靠此區機能，主要因為淡江大學就在附近，穩定的學生人口足以支撐附近的機能店家。這地點不但享有淡海重劃區開發所帶來的福利，也可以直接享受已經完整的生活機能．', Decimal('25.17850280000000000'), Decimal('121.45499080000000000'), 251)
# (4, 'http://rent.yungching.com.tw/house/924508/', '2016-12-17', '淡水捷運站前中山路套房月租5000', '新北市淡水區中山路', '套', 'N', 'N', 'N', 'N', 'N', Decimal('7.00'), 5000, 4, 0, 'NA', 'NA', '房屋描述淡水捷運站前中山路套房月租5000交通便利、臨近淡水商圈。是個食衣住行皆便利的地點。屋況佳，傢俱家電全配、內含數位電視。兩間獨立套房亦可以只租一間獨立套房，兩間獨立套房月租1萬、一間獨立套房月租5千。', Decimal('25.17091820000000000'), Decimal('121.44183650000000000'), 251)
# (5, 'http://rent.yungching.com.tw/house/857007/', '2016-11-16', '鳳吉二街套房', '新北市鶯歌區鳳吉二街', '套', 'N', 'N', 'N', 'N', 'N', Decimal('7.99'), 6000, 3, 5, 'NA', 'NA', '房屋描述鳳吉二街套房全新整理附全新傢俱、床組、冰箱、桌椅、電視', Decimal('24.97404710000000000'), Decimal('121.32713450000000000'), 239)
# (6, 'http://rent.yungching.com.tw/house/799307/', '2017-06-19', '捷運英專套房', '新北市淡水區英專路', '套', 'N', 'A', 'N', 'N', 'N', Decimal('8.00'), 6500, 4, 0, '水泥', 'NA', '房屋描述捷運英專套房約8坪租金實在，近夜市及捷運傢俱加電都有(、冰箱、冷氣)', Decimal('25.17119990000000000'), Decimal('121.44574870000000000'), 251)
# (7, 'http://rent.yungching.com.tw/house/1279374/', '2017-08-16', '普羅輕軌站三房車', '新北市淡水區新市一路三段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('46.83'), 23000, 6, 0, '水泥', 'NA', '房屋描述普羅輕軌站三房車1.捷運輕軌站旁2.24小時保全管理3.附平面車位4.新市鎮商圈區，生活機能佳', Decimal('25.18295090000000000'), Decimal('121.44675330000000000'), 251)
# (8, 'http://rent.yungching.com.tw/house/1279343/', '2017-08-16', '公園美裝公寓二樓', '台北市士林區中山北路七段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('41.67'), 35000, 2, 5, '5', 'NA', '房屋描述公園美裝公寓二樓', Decimal('25.12304930000000000'), Decimal('121.53208110000000000'), 111)
# (9, 'http://rent.yungching.com.tw/house/1279341/', '2017-08-16', '公園景觀精美三房', '台北市士林區德行東路', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('37.84'), 30000, 3, 5, '5', 'NA', '房屋描述公園景觀精美三房稀有正面公園精美屋況景觀宅', Decimal('25.10923830000000000'), Decimal('121.53271460000000000'), 111)
# (10, 'http://rent.yungching.com.tw/house/1279340/', '2017-08-16', '士林福港機能雅房', '台北市士林區福港街', '住', 'N', 'A', 'N', 'N', 'N', Decimal('8.00'), 8300, 4, 4, '4', 'NA', '房屋描述士林福港機能雅房近士林夜市劍潭站河濱公園', Decimal('25.08720390000000000'), Decimal('121.51784780000000000'), 111)
# (11, 'http://rent.yungching.com.tw/house/1279336/', '2017-08-16', '捷運電梯高樓三房', '台北市信義區和平東路三段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('41.82'), 32000, 9, 12, '12', 'NA', '房屋描述捷運電梯高樓三房高樓電梯三房近捷運走路約6分鐘', Decimal('25.02064780000000000'), Decimal('121.55659140000000000'), 110)
# (12, 'http://rent.yungching.com.tw/house/1279330/', '2017-08-16', '近台電辦公四房', '台北市大安區羅斯福路三段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('44.00'), 42000, 4, 12, '12', 'NA', '房屋描述近台電辦公四房面羅斯福路近台電捷運大四房', Decimal('25.02036840000000000'), Decimal('121.52868240000000000'), 106)
# (13, 'http://rent.yungching.com.tw/house/1279329/', '2017-08-16', '明曜名人巷辦公', '台北市大安區仁愛路四段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('75.20'), 125000, 2, 13, '13', 'NA', '房屋描述明曜名人巷辦公近忠孝敦化捷運站百貨各式餐飲店家', Decimal('25.03765620000000000'), Decimal('121.55097860000000000'), 106)
# (14, 'http://rent.yungching.com.tw/house/1279328/', '2017-08-16', '台大新象高樓三房', '台北市大安區新生南路三段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('51.51'), 70000, 7, 22, '22', 'NA', '房屋描述台大新象高樓三房高樓遠景', Decimal('25.02119740000000000'), Decimal('121.53414570000000000'), 106)
# (15, 'http://rent.yungching.com.tw/house/1279326/', '2017-08-16', '新莊捷運美寓', '新北市新莊區中興街', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('22.30'), 16800, 4, 4, '水泥', 'NA', '房屋描述新莊捷運美寓新莊捷運環境清幽稀有地點生活機能', Decimal('25.03684480000000000'), Decimal('121.44922280000000000'), 242)
# (16, 'http://rent.yungching.com.tw/house/1279325/', '2017-08-16', '大湖公園電梯兩房', '台北市內湖區大湖街', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('21.57'), 27000, 6, 1, '1', 'NA', '房屋描述大湖公園電梯兩房近公園、捷運站', Decimal('25.09844080000000000'), Decimal('121.60485210000000000'), 114)
# (17, 'http://rent.yungching.com.tw/house/1279323/', '2017-08-16', '美國學校庭院一樓', '台北市士林區中山北路七段', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('63.69'), 98000, 1, 7, '7', 'NA', '房屋描述美國學校庭院一樓近美國學校新光三越正天母機能完善', Decimal('25.12304930000000000'), Decimal('121.53208110000000000'), 111)
# (18, 'http://rent.yungching.com.tw/house/1279322/', '2017-08-16', '美麗華景觀套房', '台北市內湖區文湖街', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('21.88'), 26000, 8, 8, '8', 'NA', '房屋描述美麗華景觀套房', Decimal('25.08671850000000000'), Decimal('121.56271080000000000'), 114)
# (19, 'http://rent.yungching.com.tw/house/1279321/', '2017-08-16', '五期名人賞', '台北市內湖區新豐街', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('74.05'), 75000, 5, 15, '15', 'NA', '房屋描述五期名人賞千坪基地，雙拼規劃', Decimal('25.06022470000000000'), Decimal('121.58385950000000000'), 114)
# (20, 'http://rent.yungching.com.tw/house/1279319/', '2017-08-16', '領御光之豪邸', '新北市板橋區中山路一段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('67.71'), 60000, 7, 29, '其他：白磚', 'NA', '房屋描述領御光之豪邸全新未入住新板豪邸四房', Decimal('25.01176010000000000'), Decimal('121.46537370000000000'), 220)
# (21, 'http://rent.yungching.com.tw/house/1279318/', '2017-08-16', '東門捷運信義雙璽', '台北市中正區信義路二段', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('91.78'), 80000, 8, 13, '13', 'NA', '房屋描述東門捷運信義雙璽樓下就是東門捷運站', Decimal('25.03397710000000000'), Decimal('121.52848990000000000'), 100)
# (22, 'http://rent.yungching.com.tw/house/1279313/', '2017-08-16', '新都廳四房車', '新北市板橋區漢生東路', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('60.00'), 88000, 22, 23, '水泥', 'NA', '房屋描述新都廳四房車', Decimal('25.01270080000000000'), Decimal('121.46891690000000000'), 220)
# (23, 'http://rent.yungching.com.tw/house/1279312/', '2017-08-16', '內湖彩虹河濱4房', '台北市內湖區新明路', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('44.70'), 42000, 10, 14, '14', 'NA', '房屋描述內湖彩虹河濱4房面河景', Decimal('25.05671550000000000'), Decimal('121.58395670000000000'), 114)
# (24, 'http://rent.yungching.com.tw/house/1279311/', '2017-08-16', '艷冠風水裝潢四房', '台北市內湖區民權東路六段', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('84.51'), 70000, 4, 11, '11', 'NA', '房屋描述艷冠風水裝潢四房全百萬裝潢，高級豪宅，外商首選', Decimal('25.06908340000000000'), Decimal('121.58920120000000000'), 114)
# (25, 'http://rent.yungching.com.tw/house/1279308/', '2017-08-16', '古亭捷運德林行館', '台北市中正區南昌路二段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('14.48'), 25000, 2, 13, '13', 'NA', '房屋描述古亭捷運德林行館24小時管理收垃圾', Decimal('25.02613500000000000'), Decimal('121.52191110000000000'), 100)
# (26, 'http://rent.yungching.com.tw/house/1279307/', '2017-08-16', '仁愛電梯兩房車位', '台北市中正區仁愛路二段', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('29.76'), 35000, 2, 6, '6', 'NA', '房屋描述仁愛電梯兩房車位緊鄰仁愛路', Decimal('25.03821790000000000'), Decimal('121.52901810000000000'), 100)
# (27, 'http://rent.yungching.com.tw/house/1279303/', '2017-08-16', '伊吉邦美居', '新北市新莊區新北大道七段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('17.22'), 15000, 6, 18, '木板', 'NA', '房屋描述伊吉邦美居', Decimal('25.03059090000000000'), Decimal('121.41360630000000000'), 242)
# (28, 'http://rent.yungching.com.tw/house/1279296/', '2017-08-16', '龍江明亮寬敞辦公', '台北市中山區龍江路', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('43.81'), 35000, 7, 10, '10', 'NA', '房屋描述龍江明亮寬敞辦公', Decimal('25.05749470000000000'), Decimal('121.54059610000000000'), 104)
# (29, 'http://rent.yungching.com.tw/house/1279295/', '2017-08-16', '哈佛大空間一樓', '新北市新店區永平街', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('61.40'), 35000, 1, 9, '水泥', 'NA', '房屋描述哈佛大空間一樓可隔成四房附車位使用生活機能棒', Decimal('24.98463900000000000'), Decimal('121.51610660000000000'), 231)
# (30, 'http://rent.yungching.com.tw/house/1279294/', '2017-08-16', '忠泰河岸交響曲', '台北市中山區堤頂大道二段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('141.10'), 250000, 10, 13, '13', 'NA', '房屋描述忠泰河岸交響曲河岸第一排景觀超美', Decimal('25.07809380000000000'), Decimal('121.56648740000000000'), 114)
# (31, 'http://rent.yungching.com.tw/house/1279291/', '2017-08-16', '正八德住店', '台北市中山區八德路二段', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('31.67'), 25000, 3, 5, '5', 'NA', '房屋描述正八德住店', Decimal('25.04646280000000000'), Decimal('121.53913550000000000'), 10491)
# (32, 'http://rent.yungching.com.tw/house/1279281/', '2017-08-16', '大安東豐2樓美寓', '台北市大安區東豐街', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('30.41'), 28000, 2, 4, '4', 'NA', '房屋描述大安東豐2樓美寓標準三房公寓二樓免爬高格局方正', Decimal('25.03600990000000000'), Decimal('121.54600490000000000'), 106)
# (33, 'http://rent.yungching.com.tw/house/1279280/', '2017-08-16', '東區微風三角辦公', '台北市大安區復興南路一段', '住', 'N', 'A', 'N', 'N', 'N', Decimal('32.99'), 50000, 2, 12, '12', 'NA', '房屋描述東區微風三角辦公', Decimal('25.03902510000000000'), Decimal('121.54379450000000000'), 106)
# (34, 'http://rent.yungching.com.tw/house/1279277/', '2017-08-16', '皇族高樓電梯兩房', '台北市大同區民族西路', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('26.00'), 30000, 8, 11, '11', 'NA', '房屋描述皇族高樓電梯兩房', Decimal('25.06862260000000000'), Decimal('121.51439450000000000'), 103)
# (35, 'http://rent.yungching.com.tw/house/1279274/', '2017-08-16', '京站美妝兩房', '台北市大同區市民大道一段', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('25.19'), 50000, 13, 18, '18', 'NA', '房屋描述京站美妝兩房食衣住行育樂垂直整合生活超便利', Decimal('25.04870560000000000'), Decimal('121.51741940000000000'), 103)
# (36, 'http://rent.yungching.com.tw/house/1279272/', '2017-08-16', '世界敦南雅典小品', '台北市大安區四維路', '住', 'N', 'A', 'N', 'N', 'N', Decimal('21.53'), 25000, 6, 8, '8', 'NA', '房屋描述世界敦南雅典小品物業管理公司,管理嚴謹,進出單純', Decimal('25.03096360000000000'), Decimal('121.54799060000000000'), 106)
# (37, 'http://rent.yungching.com.tw/house/1279269/', '2017-08-16', '正義精美裝潢兩房', '台北市大安區忠孝東路三段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('35.16'), 45000, 6, 14, '14', 'NA', '房屋描述正義精美裝潢兩房近捷運周邊生活機能豐富', Decimal('25.04176420000000000'), Decimal('121.53821630000000000'), 106)
# (38, 'http://rent.yungching.com.tw/house/1279265/', '2017-08-16', '天母磺溪美寓', '台北市北投區天母西路', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('36.00'), 35000, 3, 5, '5', 'NA', '房屋描述天母磺溪美寓', Decimal('25.11868750000000000'), Decimal('121.52384950000000000'), 112)
# (39, 'http://rent.yungching.com.tw/house/1279264/', '2017-08-16', '木新方正大三房', '台北市文山區木新路三段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('30.12'), 20000, 4, 4, '4', 'NA', '房屋描述木新方正大三房', Decimal('24.98139480000000000'), Decimal('121.55948780000000000'), 116)
# (40, 'http://rent.yungching.com.tw/house/1279263/', '2017-08-16', '捷運挑高4米一樓', '台北市文山區景後街', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('50.43'), 60000, 1, 15, '15', 'NA', '房屋描述捷運挑高4米一樓位於景美市中心近捷運旁邊商家林立', Decimal('24.99085270000000000'), Decimal('121.54238400000000000'), 116)
# (41, 'http://rent.yungching.com.tw/house/1279261/', '2017-08-16', '興隆一樓', '台北市文山區興隆路四段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('26.51'), 23000, 1, 4, '4', 'NA', '房屋描述興隆一樓邊間，屋況佳，一樓門前方便進出', Decimal('24.98662340000000000'), Decimal('121.56087520000000000'), 116)
# (42, 'http://rent.yungching.com.tw/house/1279259/', '2017-08-16', '政大華府套房', '台北市文山區指南路二段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('9.47'), 15000, 5, 7, '7', 'NA', '房屋描述政大華府套房政大平地有社區管理套房', Decimal('24.98748440000000000'), Decimal('121.57665310000000000'), 116)
# (43, 'http://rent.yungching.com.tw/house/1279258/', '2017-08-16', '閱讀春樹邊間3房', '台北市文山區興隆路三段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('44.03'), 38000, 6, 14, '14', 'NA', '房屋描述閱讀春樹邊間3房鄰近再興中學', Decimal('24.99527660000000000'), Decimal('121.55968520000000000'), 116)
# (44, 'http://rent.yungching.com.tw/house/1279256/', '2017-08-16', '武成小資租屋', '台北市萬華區武成街', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('14.68'), 12000, 3, 3, '3', 'NA', '房屋描述武成小資租屋', Decimal('25.01906040000000000'), Decimal('121.49465480000000000'), 108)
# (45, 'http://rent.yungching.com.tw/house/1279254/', '2017-08-16', '西門3房2廳2衛', '台北市萬華區開封街二段', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('37.00'), 35000, 6, 9, '9', 'NA', '房屋描述西門3房2廳2衛近西門捷運生活機能超優渥', Decimal('25.04656490000000000'), Decimal('121.50702960000000000'), 108)
# (46, 'http://rent.yungching.com.tw/house/1279252/', '2017-08-16', '第一名宅', '台北市萬華區開封街二段', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('20.74'), 28000, 7, 14, '14', 'NA', '房屋描述第一名宅近捷運公園運動中心', Decimal('25.04656490000000000'), Decimal('121.50702960000000000'), 108)
# (47, 'http://rent.yungching.com.tw/house/1279251/', '2017-08-16', '青年新城電梯3房', '台北市萬華區青年路', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('33.24'), 32000, 10, 12, '12', 'NA', '房屋描述青年新城電梯3房', Decimal('25.02317830000000000'), Decimal('121.50271120000000000'), 108)
# (48, 'http://rent.yungching.com.tw/house/1279248/', '2017-08-16', '輝煌年代大空間', '新北市永和區中山路一段', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('70.70'), 48000, 8, 12, '水泥', 'NA', '房屋描述輝煌年代大空間一層一戶', Decimal('25.00893070000000000'), Decimal('121.50930080000000000'), 234)
# (49, 'http://rent.yungching.com.tw/house/1279246/', '2017-08-16', '萬囍芳鄰三房一樓', '台北市萬華區德昌街', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('20.15'), 22000, 1, 2, '2', 'NA', '房屋描述萬囍芳鄰三房一樓生活機能佳屋況好靜巷一樓', Decimal('25.02395990000000000'), Decimal('121.49612520000000000'), 108)
# (50, 'http://rent.yungching.com.tw/house/1279230/', '2017-08-16', '捷運小貴馥', '台北市士林區福德路', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('10.55'), 23000, 3, 3, '3', 'NA', '房屋描述捷運小貴馥24小時物業管理、近捷運站', Decimal('25.09203240000000000'), Decimal('121.52342170000000000'), 111)
# (51, 'http://rent.yungching.com.tw/house/1279229/', '2017-08-16', '中央捷運雙景四房', '新北市新店區中央三街', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('90.75'), 45000, 21, 24, '水泥', 'NA', '房屋描述中央捷運雙景四房三面採光，平面大車位，雙主臥室', Decimal('24.97478280000000000'), Decimal('121.52715680000000000'), 231)
# (52, 'http://rent.yungching.com.tw/house/1279227/', '2017-08-16', '雙連捷運小套房', '台北市中山區中山北路二段', '住', 'N', 'A', 'N', 'N', 'N', Decimal('4.00'), 8000, 2, 2, '2', 'NA', '房屋描述雙連捷運小套房', Decimal('25.06012420000000000'), Decimal('121.52306920000000000'), 10491)
# (53, 'http://rent.yungching.com.tw/house/1279225/', '2017-08-16', '台北瑞士溫馨3房', '新北市中和區華新街', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('27.22'), 25000, 13, 14, '14', 'NA', '房屋描述台北瑞士溫馨3房高樓有景觀', Decimal('24.98397210000000000'), Decimal('121.50810250000000000'), 235)
# (54, 'http://rent.yungching.com.tw/house/1279218/', '2017-08-16', '租掉了不要看', '台北市大同區赤峰街', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('24.00'), 28000, 2, 5, '5', 'NA', '房屋描述租掉了不要看中山站走路約兩分鐘，機能完善', Decimal('25.05531610000000000'), Decimal('121.51963510000000000'), 103)
# (55, 'http://rent.yungching.com.tw/house/1279215/', '2017-08-16', '遠雄日光三房車位', '台北市文山區木柵路三段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('71.68'), 50000, 8, 24, '24', 'NA', '房屋描述遠雄日光三房車位木柵市中心鋼骨電梯大樓', Decimal('24.98866130000000000'), Decimal('121.56723290000000000'), 116)
# (56, 'http://rent.yungching.com.tw/house/1279213/', '2017-08-16', '水都河景大戶', '新北市永和區環河東路四段', '住', 'N', 'N', 'N', 'N', 'Y', Decimal('58.00'), 50000, 27, 28, 'NA', 'NA', '房屋描述水都河景大戶', Decimal('24.99756430000000000'), Decimal('121.52830120000000000'), 234)
# (57, 'http://rent.yungching.com.tw/house/1279211/', '2017-08-16', '京站精美住辦', '台北市大同區市民大道一段', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('15.43'), 32000, 14, 18, '18', 'NA', '房屋描述京站精美住辦五鐵構共，電影院，百貨當鄰居', Decimal('25.04870560000000000'), Decimal('121.51741940000000000'), 103)
# (58, 'http://rent.yungching.com.tw/house/1279208/', '2017-08-16', '民生東路捷運辦公', '台北市中山區民生東路一段', '住', 'N', 'A', 'N', 'Y', 'N', Decimal('38.16'), 40000, 3, 12, '12', 'NA', '房屋描述民生東路捷運辦公近捷運，面公園', Decimal('25.05805580000000000'), Decimal('121.52525810000000000'), 10491)
# (59, 'http://rent.yungching.com.tw/house/1279207/', '2017-08-16', 'JR羅斯福面山景', '台北市文山區萬盛街', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('33.90'), 35000, 5, 8, '8', 'NA', '房屋描述JR羅斯福面山景近捷運面山景', Decimal('25.00601830000000000'), Decimal('121.54067200000000000'), 116)
# (60, 'http://rent.yungching.com.tw/house/1279206/', '2017-08-16', '閱讀春樹3房', '台北市文山區興隆路三段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('45.79'), 53000, 3, 15, '15', 'NA', '房屋描述閱讀春樹3房全新成屋附裝潢', Decimal('24.99527660000000000'), Decimal('121.55968520000000000'), 116)
# (61, 'http://rent.yungching.com.tw/house/1279204/', '2017-08-16', '天母東路大三房', '台北市士林區天母東路', '住', 'N', 'N', 'N', 'N', 'N', Decimal('39.90'), 32000, 4, 5, '5', 'NA', '房屋描述天母東路大三房', Decimal('25.11814010000000000'), Decimal('121.53458500000000000'), 111)
# (62, 'http://rent.yungching.com.tw/house/1279203/', '2017-08-16', '達觀A1高樓兩房', '新北市新店區達觀路', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('23.20'), 14000, 17, 19, '水泥', 'NA', '房屋描述達觀A1高樓兩房', Decimal('24.94137200000000000'), Decimal('121.50309200000000000'), 231)
# (63, 'http://rent.yungching.com.tw/house/1279202/', '2017-08-16', '湯泉美地溫馨美居', '新北市新店區溪園路', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('21.30'), 22000, 7, 14, '木板', 'NA', '房屋描述湯泉美地溫馨美居二改一房，屋況佳，寧靜舒適', Decimal('24.98380020000000000'), Decimal('121.52598710000000000'), 231)
# (64, 'http://rent.yungching.com.tw/house/1279201/', '2017-08-16', '湯泉櫻花寧靜四房', '新北市新店區溪園路', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('65.69'), 48000, 7, 14, '木板', 'NA', '房屋描述湯泉櫻花寧靜四房前後陽台，一層兩戶，寧靜不吵', Decimal('24.98380020000000000'), Decimal('121.52598710000000000'), 231)
# (65, 'http://rent.yungching.com.tw/house/1279198/', '2017-08-16', '國館捷運電梯三房', '台北市大安區延吉街', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('41.95'), 38000, 3, 6, '6', 'NA', '房屋描述國館捷運電梯三房近國父紀念館捷運站雙併電梯大三房', Decimal('25.03872870000000000'), Decimal('121.55518100000000000'), 106)
# (66, 'http://rent.yungching.com.tw/house/1279195/', '2017-08-16', '萬芳醫院捷運３房', '台北市文山區興隆路三段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('30.00'), 22000, 4, 5, '5', 'NA', '房屋描述萬芳醫院捷運３房近捷運大馬路邊安全性高生活機能強', Decimal('24.99527660000000000'), Decimal('121.55968520000000000'), 116)
# (67, 'http://rent.yungching.com.tw/house/1279190/', '2017-08-16', '公教尊邸三房坡車', '台北市士林區基河路', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('36.74'), 36000, 7, 9, '9', 'NA', '房屋描述公教尊邸三房坡車近捷運,學校.24小時保全管理', Decimal('25.09104940000000000'), Decimal('121.52175980000000000'), 111)
# (68, 'http://rent.yungching.com.tw/house/1279188/', '2017-08-16', '民生東路公園辦公', '台北市中山區民生東路一段', '住', 'N', 'A', 'N', 'Y', 'N', Decimal('43.85'), 45000, 3, 12, '12', 'NA', '房屋描述民生東路公園辦公近捷運、正面公園', Decimal('25.05805580000000000'), Decimal('121.52525810000000000'), 10491)
# (69, 'http://rent.yungching.com.tw/house/1279187/', '2017-08-16', '中央新村3+1房', '新北市新店區中央七街', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('49.13'), 32000, 3, 5, '木板', 'NA', '房屋描述中央新村3+1房四改三房，一層一戶，寧靜舒適', Decimal('24.97624220000000000'), Decimal('121.52805050000000000'), 231)
# (70, 'http://rent.yungching.com.tw/house/1279186/', '2017-08-16', '面公園4房美寓', '台北市內湖區內湖路三段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('47.68'), 38000, 3, 5, '5', 'NA', '房屋描述面公園4房美寓', Decimal('25.09047380000000000'), Decimal('121.58189930000000000'), 114)
# (71, 'http://rent.yungching.com.tw/house/1279185/', '2017-08-16', '北投站雲天小套房', '台北市北投區溫泉路', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('13.77'), 16000, 9, 12, '12', 'NA', '房屋描述北投站雲天小套房生活機能便利', Decimal('25.13616180000000000'), Decimal('121.50861920000000000'), 112)
# (72, 'http://rent.yungching.com.tw/house/1279184/', '2017-08-16', '中和國小旁套房', '新北市中和區中和路', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('6.77'), 65000000, 14, 18, '水泥', 'NA', '房屋描述中和國小旁套房完整學區.交通', Decimal('24.99969080000000000'), Decimal('121.50593240000000000'), 235)
# (73, 'http://rent.yungching.com.tw/house/1279183/', '2017-08-16', '景興學區大3房', '台北市文山區景興路', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('41.00'), 28000, 3, 1, '1', 'NA', '房屋描述景興學區大3房近學校公園頂好', Decimal('24.99315430000000000'), Decimal('121.54438350000000000'), 116)
# (74, 'http://rent.yungching.com.tw/house/1279163/', '2017-08-16', '七段大氣車位美廈', '台北市士林區中山北路七段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('70.66'), 60000, 5, 7, '7', 'NA', '房屋描述七段大氣車位美廈靜巷、近公園、近公車站', Decimal('25.12304930000000000'), Decimal('121.53208110000000000'), 111)
# (75, 'http://rent.yungching.com.tw/house/1279162/', '2017-08-16', '頂溪新時代', '新北市永和區中山路一段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('17.03'), 19000, 6, 15, '水泥', 'NA', '房屋描述頂溪新時代走路捷運約5分鐘', Decimal('25.00893070000000000'), Decimal('121.50930080000000000'), 234)
# (76, 'http://rent.yungching.com.tw/house/1279160/', '2017-08-16', '後山埤高樓電梯', '台北市南港區忠孝東路五段', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('37.68'), 49000000, 8, 12, '12', 'NA', '房屋描述後山埤高樓電梯地點好,生活機能佳', Decimal('25.04468130000000000'), Decimal('121.58233400000000000'), 115)
# (77, 'http://rent.yungching.com.tw/house/1279159/', '2017-08-16', '松江明珠高樓邊間', '台北市中山區松江路', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('11.69'), 28000, 8, 11, '11', 'NA', '房屋描述松江明珠高樓邊間高樓挑高採光通風佳', Decimal('25.05955140000000000'), Decimal('121.53300450000000000'), 10491)
# (78, 'http://rent.yungching.com.tw/house/1279158/', '2017-08-16', '裝潢美屋隔間套房', '台北市北投區大業路', '住', 'N', 'N', 'N', 'N', 'Y', Decimal('8.00'), 13500, 3, 4, '4', 'NA', '房屋描述裝潢美屋隔間套房鄰近捷運交通方便靜巷住宅環境好', Decimal('25.12666380000000000'), Decimal('121.49827450000000000'), 112)
# (79, 'http://rent.yungching.com.tw/house/1279153/', '2017-08-16', '安和靜巷四房美寓', '台北市大安區安和路一段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('31.87'), 35000, 3, 4, '4', 'NA', '房屋描述安和靜巷四房美寓靜巷住宅區，臨近信義安和捷運站', Decimal('25.03716930000000000'), Decimal('121.55159150000000000'), 106)
# (80, 'http://rent.yungching.com.tw/house/1279151/', '2017-08-16', '東區電梯美寓', '台北市大安區大安路一段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('38.51'), 45000, 6, 7, '7', 'NA', '房屋描述東區電梯美寓捷運、東區商圈、靜巷', Decimal('25.03916670000000000'), Decimal('121.54606980000000000'), 106)
# (81, 'http://rent.yungching.com.tw/house/1279148/', '2017-08-16', '仁愛林蔭鋼骨名邸', '台北市中正區仁愛路二段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('88.51'), 145000, 10, 19, '19', 'NA', '房屋描述仁愛林蔭鋼骨名邸正仁愛林蔭鋼骨全天候管理屋況好', Decimal('25.03821790000000000'), Decimal('121.52901810000000000'), 100)
# (82, 'http://rent.yungching.com.tw/house/1279143/', '2017-08-16', '天母西路管理大廈', '台北市士林區天母西路', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('59.05'), 60000, 3, 7, '7', 'NA', '房屋描述天母西路管理大廈', Decimal('25.11843500000000000'), Decimal('121.52703630000000000'), 111)
# (83, 'http://rent.yungching.com.tw/house/1279141/', '2017-08-16', '畫世紀邊間兩房', '新北市板橋區漢生東路', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('32.64'), 38000, 23, 29, '水泥', 'NA', '房屋描述畫世紀邊間兩房邊間裝潢好利用', Decimal('25.01270080000000000'), Decimal('121.46891690000000000'), 220)
# (84, 'http://rent.yungching.com.tw/house/1279140/', '2017-08-16', '畢卡索兩房', '台北市信義區光復南路', '住', 'N', 'N', 'N', 'N', 'Y', Decimal('20.18'), 23000, 8, 12, '12', 'NA', '房屋描述畢卡索兩房知名昇陽建設.管理優', Decimal('25.03894390000000000'), Decimal('121.55754370000000000'), 106)
# (85, 'http://rent.yungching.com.tw/house/1279137/', '2017-08-16', '黃金中山國中金店', '台北市松山區民權東路三段', '住', 'N', 'A', 'N', 'N', 'N', Decimal('31.48'), 44000, 1, 10, '10', 'NA', '房屋描述黃金中山國中金店近捷運,附近人潮多', Decimal('25.06197960000000000'), Decimal('121.54748620000000000'), 105)
# (86, 'http://rent.yungching.com.tw/house/1279134/', '2017-08-16', '冠德君悅簡約豪邸', '台北市中山區長安東路二段', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('44.26'), 55000, 5, 14, '14', 'NA', '房屋描述冠德君悅簡約豪邸新屋裝潢極新邊間有浴缸百米綠蔭景', Decimal('25.04839360000000000'), Decimal('121.53671580000000000'), 10491)
# (87, 'http://rent.yungching.com.tw/house/1279133/', '2017-08-16', '江翠捷運昇陽二房', '新北市板橋區莊敬路', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('25.17'), 28000, 22, 24, '水泥', 'NA', '房屋描述江翠捷運昇陽二房捷運小家庭入住優質推薦', Decimal('25.02530110000000000'), Decimal('121.47188740000000000'), 220)
# (88, 'http://rent.yungching.com.tw/house/1279128/', '2017-08-16', '橋峰美式豪邸', '新北市板橋區中山路一段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('103.82'), 85000, 15, 31, '水泥', 'NA', '房屋描述橋峰美式豪邸美式裝潢開擴客廳', Decimal('25.01176010000000000'), Decimal('121.46537370000000000'), 220)
# (89, 'http://rent.yungching.com.tw/house/1279120/', '2017-08-16', '遠眺山景居', '台北市信義區信義路五段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('15.27'), 30000, 14, 19, '19', 'NA', '房屋描述遠眺山景居高樓層面山景，裝潢極美即刻入住', Decimal('25.03279760000000000'), Decimal('121.56713740000000000'), 110)
# (90, 'http://rent.yungching.com.tw/house/1279116/', '2017-08-16', '領御 天際新板', '新北市板橋區中山路一段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('67.50'), 70000, 8, 29, '其他：白磚', 'NA', '房屋描述領御 天際新板邊間新板特區三房', Decimal('25.01176010000000000'), Decimal('121.46537370000000000'), 220)
# (91, 'http://rent.yungching.com.tw/house/1279114/', '2017-08-16', '天玉街裝潢美廈', '台北市士林區天玉街', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('46.30'), 60000, 5, 7, '7', 'NA', '房屋描述天玉街裝潢美廈鄰近天母國小安靜巷道', Decimal('25.12123200000000000'), Decimal('121.52917650000000000'), 111)
# (92, 'http://rent.yungching.com.tw/house/1279113/', '2017-08-16', '公所捷運吉美君品', '新北市新店區中正路', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('107.74'), 96000, 5, 28, '水泥', 'NA', '房屋描述公所捷運吉美君品近公所捷運吉美建設全新成屋雙車', Decimal('24.98024420000000000'), Decimal('121.53388340000000000'), 231)
# (93, 'http://rent.yungching.com.tw/house/1279097/', '2017-08-16', '北門面寬一樓', '台北市大同區延平北路一段', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('7.59'), 7900, 1, 2, '2', 'NA', '房屋描述北門面寬一樓單純一樓獨立進出稀有小坪數', Decimal('25.05130460000000000'), Decimal('121.51192520000000000'), 103)
# (94, 'http://rent.yungching.com.tw/house/1279095/', '2017-08-16', '天母國小3房華廈', '台北市士林區天母北路', '住', 'N', 'A', 'N', 'Y', 'Y', Decimal('36.51'), 45000, 7, 7, '7', 'NA', '房屋描述天母國小3房華廈格局方正採光通風家戶數單純', Decimal('25.12089860000000000'), Decimal('121.52662150000000000'), 111)
# (95, 'http://rent.yungching.com.tw/house/1279084/', '2017-08-16', '伊吉邦挑高美宅', '新北市新莊區新北大道七段', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('22.90'), 15500, 18, 18, '木板', 'NA', '房屋描述伊吉邦挑高美宅近迴龍站及貴和站交通便捷', Decimal('25.03059090000000000'), Decimal('121.41360630000000000'), 242)
# (96, 'http://rent.yungching.com.tw/house/1279083/', '2017-08-16', '捷運甜蜜蜜小資宅', '新北市新莊區萬安街', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('25.11'), 19000, 13, 15, '水泥', 'NA', '房屋描述捷運甜蜜蜜小資宅', Decimal('25.02307610000000000'), Decimal('121.42086590000000000'), 242)
# (97, 'http://rent.yungching.com.tw/house/1278847/', '2017-08-16', '租81鴻宇堂5樓', '新北市鶯歌區中山路', '住', 'N', 'N', 'N', 'N', 'N', Decimal('33.42'), 18000, 5, 9, 'NA', 'NA', '房屋描述租81鴻宇堂5樓近建國國小光明商圈市場公園交通四通八達高級建材設計現代感住宅', Decimal('24.95699590000000000'), Decimal('121.34799510000000000'), 239)
# (98, 'http://rent.yungching.com.tw/house/1278713/', '2017-08-16', '福德分租套房', '新北市汐止區福德三路', '套', 'N', 'A', 'N', 'Y', 'N', Decimal('37.37'), 7600, 4, 7, 'NA', 'NA', '房屋描述福德分租套房交通便利套房設備齊全', Decimal('25.06720090000000000'), Decimal('121.63201890000000000'), 221)
# (99, 'http://rent.yungching.com.tw/house/1278182/', '2017-08-15', '山海大地', '新北市淡水區淡金路', '套', 'N', 'A', 'N', 'N', 'Y', Decimal('14.89'), 11000, 8, 20, '水泥', 'NA', '房屋描述山海大地標準一房一廳，格局方正，採光佳，有陽台附家具、電。', Decimal('25.16596940000000000'), Decimal('121.45898160000000000'), 251)
# (100, 'http://rent.yungching.com.tw/house/1278160/', '2017-08-15', '尚海大器3房', '新北市淡水區淡金路', '住', 'N', 'A', 'N', 'N', 'Y', Decimal('78.96'), 45000, 6, 19, '水泥', 'NA', '房屋描述尚海大器3房千坪中庭花園，公設完善，游泳池，SPA。一卡皮箱可入住，飯店式管理。紅樹林富人灣，慢活人生、夕陽、水筆仔、觀音山。', Decimal('25.16596940000000000'), Decimal('121.45898160000000000'), 251)

# %%
# !pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-0.7.11-py2.py3-none-any.whl (78kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-0.7.11

# %%
import pymysql
import redis

#redis connection
r = redis.StrictRedis(host='localhost', port=6379, db=0)

#connect maria rdb
db = pymysql.connect(
        host='10.120.27.2',
        user='root',
        passwd='1234',
        db='rental',
        charset='utf8mb4'
    )
#設置cursor
cursor = db.cursor()
#cursor.execute('SELECT * FROM typeID;')

# %%
cursor.execute('SELECT * FROM typeID;')
typeID = cursor.fetchall()
for typeid,typename in typeID:
    print(typeid,typename)
# Out:
# 201 Bus
# 202 MRT
# 203 Train
# 204 UBike
# 205 Exam
# 206 Charger
# 207 Towing
# 301 BookStore
# 302 DepartmentStore
# 303 Library
# 304 Museum
# 305 Theater
# 401 Park
# 402 Scenic
# 403 Sport
# 501 School
# 502 Hospital
# 503 Pharmacy
# 504 Police
# 505 FireStation

# %%
# %%time
for typeid,typename in typeID:
    sqlstat = 'SELECT ID, lat, lng FROM baseEnviro WHERE typeID={};'.format(typeid)
    cursor.execute(sqlstat)
    results = cursor.fetchall()
    for item in results:
        r.geoadd(typename, item[2], item[1] , item[0])
        #print(item[2], item[1] , item[0])
# Out:
# Wall time: 3.77 s

# %%
# %%time
cursor.execute('SELECT ID, lat, lng FROM rentInfo;')
results = cursor.fetchall()
for item in results:
    r.geoadd('rent', item[2], item[1] , item[0])
    #print(item[2], item[1] , item[0])
# Out:
# Wall time: 1.69 s

# %%
cursor.close()

# %%
#test
member, lat, lng = cursor.fetchone()

print(member,lat,lng)

r.geoadd('rent', lng,lat , member)

# %%
r.zcard('rent')
# Out:
# 24799

# %%
list(r.zscan_iter('rent'))
# Out:
# []

# %%
# %%time
r.georadiusbymember('rent', '10', 500, withcoord=True, withdist=True)
# Out:
# Wall time: 8 ms
# [['12098', 319.9065, (121.51690810918808, 25.084456061209536)],
#  ['13085', 296.7969, (121.5162643790245, 25.08495286655677)],
#  ['13818', 287.1844, (121.5166774392128, 25.084848942989233)],
#  ['24305', 243.1275, (121.51694566011429, 25.085175922018784)],
#  ['19841', 236.0392, (121.51614636182785, 25.085743699558485)],
#  ['400', 417.9535, (121.51756256818771, 25.083454846351593)],
#  ['11437', 320.629, (121.5174874663353, 25.084339464036212)],
#  ['20199', 314.2111, (121.51763767004013, 25.084385089017076)],
#  ['24476', 314.408, (121.51707977056503, 25.084463665373015)],
#  ['18069', 293.6305, (121.517433822155, 25.08459040143098)],
#  ['19097', 291.8041, (121.51744455099106, 25.084605609757936)],
#  ['20676', 408.3973, (121.51883393526077, 25.083642415717385)],
#  ['19457', 374.2854, (121.51854425668716, 25.083898422554483)],
#  ['11286', 407.5932, (121.51915580034256, 25.08373620040029)],
#  ['24779', 399.7947, (121.51931136846542, 25.083862936458253)],
#  ['16894', 339.1867, (121.51851743459702, 25.084215262699395)],
#  ['20485', 331.2892, (121.51852279901505, 25.084288769613018)],
#  ['23300', 311.4149, (121.5185335278511, 25.084473804257648)],
#  ['24472', 285.9159, (121.51859790086746, 25.08472474165243)],
#  ['15913', 373.8287, (121.51965469121933, 25.08426849184375)],
#  ['14752', 251.0217, (121.51809364557266, 25.084957935999086)],
#  ['16825', 306.3058, (121.51947766542435, 25.084879359643146)],
#  ['1001', 224.212, (121.51941329240799, 25.085771581491237)],
#  ['1002', 224.212, (121.51941329240799, 25.085771581491237)],
#  ['1809', 224.212, (121.51941329240799, 25.085771581491237)],
#  ['1832', 224.212, (121.51941329240799, 25.085771581491237)],
#  ['1867', 224.212, (121.51941329240799, 25.085771581491237)],
#  ['1872', 224.212, (121.51941329240799, 25.085771581491237)],
#  ['2021', 224.212, (121.51941329240799, 25.085771581491237)],
#  ['3097', 224.212, (121.51941329240799, 25.085771581491237)],
#  ['3185', 224.212, (121.51941329240799, 25.085771581491237)],
#  ['3577', 224.212, (121.51941329240799, 25.085771581491237)],
#  ['3756', 224.212, (121.51941329240799, 25.085771581491237)],
#  ['4000', 224.212, (121.51941329240799, 25.085771581491237)],
#  ['5915', 224.212, (121.51941329240799, 25.085771581491237)],
#  ['5968', 224.212, (121.51941329240799, 25.085771581491237)],
#  ['6082', 224.212, (121.51941329240799, 25.085771581491237)],
#  ['6154', 224.212, (121.51941329240799, 25.085771581491237)],
#  ['6155', 224.212, (121.51941329240799, 25.085771581491237)],
#  ['6464', 224.212, (121.51941329240799, 25.085771581491237)],
#  ['6465', 224.212, (121.51941329240799, 25.085771581491237)],
#  ['6542', 224.212, (121.51941329240799, 25.085771581491237)],
#  ['6561', 224.212, (121.51941329240799, 25.085771581491237)],
#  ['9181', 171.8547, (121.51614099740982, 25.087223976715535)],
#  ['17109', 140.6475, (121.51650041341782, 25.086869115753224)],
#  ['14308', 156.1933, (121.51688665151596, 25.088306302650572)],
#  ['13272', 86.9643, (121.51736944913864, 25.086552275608305)],
#  ['6444', 55.8897, (121.51729434728622, 25.087249323927132)],
#  ['10', 0.0, (121.51784688234329, 25.08720369894626)],
#  ['2632', 0.0, (121.51784688234329, 25.08720369894626)],
#  ['2916', 0.0, (121.51784688234329, 25.08720369894626)],
#  ['3958', 0.0, (121.51784688234329, 25.08720369894626)],
#  ['7526', 0.0, (121.51784688234329, 25.08720369894626)],
#  ['576', 188.6676, (121.51971906423569, 25.087251858648287)],
#  ['14811', 75.7511, (121.51744455099106, 25.087779080649433)],
#  ['15652', 33.4818, (121.51780933141708, 25.08750279604306)],
#  ['6517', 149.6055, (121.51931673288345, 25.08739633775437)],
#  ['1184', 159.573, (121.51935428380966, 25.087644740427983)],
#  ['1242', 159.573, (121.51935428380966, 25.087644740427983)],
#  ['1834', 159.573, (121.51935428380966, 25.087644740427983)],
#  ['9212', 149.5955, (121.5184798836708, 25.088420365102742)],
#  ['8625', 355.3842, (121.51563137769699, 25.08969026040357)],
#  ['14404', 314.9704, (121.51571720838547, 25.089277100854595)],
#  ['17661', 214.5102, (121.51690274477005, 25.088932378776924)],
#  ['11326', 377.1032, (121.51655942201614, 25.09038730872239)],
#  ['23378', 286.3903, (121.51719778776169, 25.089710538172845)],
#  ['16647', 302.0694, (121.51769131422043, 25.089915850586756)],
#  ['4076', 286.0105, (121.5180453658104, 25.08976883675951)],
#  ['440', 286.0105, (121.5180453658104, 25.08976883675951)],
#  ['14734', 204.1576, (121.51845306158066, 25.088955191267367)],
#  ['21292', 238.4985, (121.51862472295761, 25.089228941152577)],
#  ['2812', 253.8874, (121.51938647031784, 25.08901095513287)],
#  ['490', 291.9685, (121.51896804571152, 25.089624357653427)],
#  ['23572', 440.675, (121.51724070310593, 25.091127447300913)],
#  ['24138', 439.5265, (121.51735335588455, 25.091129982022075)],
#  ['11582', 373.9267, (121.51872128248215, 25.090470954520647)],
#  ['2920', 370.6111, (121.51880711317062, 25.090420260097467)],
#  ['21122', 379.0678, (121.51882857084274, 25.090493767011083)],
#  ['12327', 398.1484, (121.51929527521133, 25.090534322549637)],
#  ['12503', 444.7896, (121.51844769716263, 25.091165468118312)],
#  ['16914', 446.9512, (121.51850134134293, 25.091178141724107)],
#  ['11457', 414.6674, (121.5190914273262, 25.090757378011652)],
#  ['22064', 431.8204, (121.51933819055557, 25.09084355853107)],
#  ['13847', 473.1991, (121.51880711317062, 25.08303915208146)],
#  ['13171', 486.6764, (121.51925772428513, 25.083018874312195)],
#  ['10634', 488.8743, (121.51969760656357, 25.083140540927836)],
#  ['17481', 376.2026, (121.5202447772026, 25.08461067920026)],
#  ['14664', 371.8332, (121.5202984213829, 25.08470446388315)],
#  ['1211', 483.4659, (121.52137130498886, 25.084253283516794)],
#  ['14937', 473.98, (121.52136594057083, 25.084374950132435)],
#  ['4370', 372.3928, (121.52050763368607, 25.084879359643146)],
#  ['8980', 483.3144, (121.52204185724258, 25.08509481094169)],
#  ['15818', 463.2811, (121.52203112840652, 25.08547501911559)],
#  ['1742', 477.3666, (121.52222961187363, 25.08557133851965)],
#  ['1963', 477.3666, (121.52222961187363, 25.08557133851965)],
#  ['2067', 477.3666, (121.52222961187363, 25.08557133851965)],
#  ['6247', 477.3666, (121.52222961187363, 25.08557133851965)],
#  ['6753', 477.3666, (121.52222961187363, 25.08557133851965)],
#  ['7414', 477.3666, (121.52222961187363, 25.08557133851965)],
#  ['19342', 431.2822, (121.5219184756279, 25.086004775837893)],
#  ['12013', 330.2019, (121.52093678712845, 25.08621262297296)],
#  ['8592', 228.5795, (121.52011603116989, 25.08720369894626)],
#  ['16184', 272.3786, (121.5205505490303, 25.087239185042492)],
#  ['22308', 385.4965, (121.52162879705429, 25.08667394222396)],
#  ['9526', 400.6989, (121.52178972959518, 25.086727171368302)],
#  ['15554', 229.9523, (121.52011066675186, 25.087469844667986)],
#  ['15751', 284.5804, (121.52060955762863, 25.087738525110886)],
#  ['20123', 294.6664, (121.52041107416153, 25.088478663689408)],
#  ['16445', 309.3237, (121.52056127786636, 25.088504010900998)],
#  ['11934', 364.1079, (121.52141958475113, 25.087700504293487)],
#  ['13216', 418.9364, (121.52196675539017, 25.087718247341606)],
#  ['450', 466.3407, (121.52239590883255, 25.087981858342182)],
#  ['11183', 468.2881, (121.52225643396378, 25.088536962276073)],
#  ['15898', 468.2881, (121.52225643396378, 25.088536962276073)],
#  ['22639', 475.0315, (121.52254074811935, 25.086793074118447)],
#  ['21733', 328.185, (121.52064710855484, 25.08871185803607)],
#  ['17488', 329.6906, (121.5206578373909, 25.088721996920704)],
#  ['10017', 418.8948, (121.52079194784164, 25.089862621442407)],
#  ['1103', 408.005, (121.52150005102158, 25.088787899670848)],
#  ['6861', 408.005, (121.52150005102158, 25.088787899670848)],
#  ['9869', 443.8565, (121.5216663479805, 25.08919345505634)],
#  ['23188', 432.7415, (121.52052909135818, 25.090242829616308)],
#  ['19856', 498.9553, (121.52019649744034, 25.083254603380006)],
#  ['16587', 498.4774, (121.5202072262764, 25.083264742264653)],
#  ['11926', 498.0162, (121.52022331953049, 25.083277415870448)]]

# %%
# %%time
typename = 'food'
cursor.execute('SELECT ID, lat, lng FROM baseEnviro WHERE typeID=101;')
results = cursor.fetchall()
for item in results:
    r.geoadd(typename, item[2], item[1] , item[0])
    #print(item[2], item[1] , item[0])

# %%
r.zcard('food')
# Out:
# 34493

# %%
pos = r.geopos('rent', 1)[0]

# %%
lng,lat = pos
r.georadius('food',lng,lat, 500)
# Out:
# ['28380',
#  '33886',
#  '21006',
#  '9549',
#  '33506',
#  '29029',
#  '12738',
#  '26960',
#  '29245',
#  '11110',
#  '20412',
#  '27057',
#  '28063',
#  '27649',
#  '8692',
#  '29969',
#  '30110',
#  '1633',
#  '7744',
#  '33178']

# %%
for key in r.keys():
    print(key, r.zcard(key))
# Out:
# b'UBike' 13
# b'rent' 24799
# b'FireStation' 152
# b'Police' 282
# b'Pharmacy' 967
# b'Train' 753
# b'Sport' 1332
# b'Towing' 15
# b'Hospital' 103
# b'Charger' 144
# b'Exam' 594
# b'Scenic' 936
# b'School' 2360
# b'Park' 483
# b'MRT' 121
# b'Theater' 45
# b'BookStore' 141
# b'Library' 168
# b'DepartmentStore' 70
# b'Bus' 30188
# b'Museum' 80

# %%
for key in r.keys():
    r.delete(key)

# %%
r.
